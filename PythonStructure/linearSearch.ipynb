# %%
def linear_search(list, item):
    position = 0
    if len(list) == 0:
        return -1
    for lstItem in list:
        if lstItem == item:
            return position
        else:
            position += 1
    
    return -1

# %%
tests = [
    {
        'input':{
            'list':[1,5,8,9,12,17,21,30],
            'item': 5
        },
        'output': 1
    },
    {
        'input':{
            'list':[1,5,8,9,12,17,21,30],
            'item': 1
        },
        'output': 0
    },
    {
        'input':{
            'list':[1,5,8,9,12,17,21,30],
            'item': 30
        },
        'output': 7
    },
    {
        'input':{
            'list':[1,5,8,9,12,17,21,30],
            'item': 2
        },
        'output': -1
    },
    {
        'input':{
            'list':[],
            'item': 5
        },
        'output': -1
    },
    {
        'input':{
            'list':[1,1,1,5,5,5,8,9,9,9,12,17,21,21,21,30],
            'item': 5
        },
        'output': 3
    },
    {
        'input':{
            'list':[-30,-21,-19,0,1,5,8,9,12,17,21,30],
            'item': -19
        },
        'output': 2
    },
]

# %%
from jovian.pythondsa import evaluate_test_cases
evaluate_test_cases(linear_search, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'list': [1, 5, 8, 9, 12, 17, 21, 30], 'item': 5}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'list': [1, 5, 8, 9, 12, 17, 21, 30], 'item': 1}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'list': [1, 5, 8, 9, 12, 17, 21, 30], 'item': 30}
#
# Expected Output:
# 7
#
#
# Actual Output:
# 7
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'list': [1, 5, 8, 9, 12, 17, 21, 30], 'item': 2}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'list': [], 'item': 5}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# ...
